# %%
import os
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns

# %%
# import warnings filter
from warnings import simplefilter

# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
data_ori = pd.read_csv('climate_change.csv')
print(data_ori.shape)
# types
print(data_ori.dtypes)
# feature names
print(list(data_ori))
# head
print(data_ori.head(6))
# descriptions, change precision to 2 places
print(data_ori.describe())
# Out:
# (308, 11)
# Year          int64
# Month         int64
# MEI         float64
# CO2         float64
# CH4         float64
# N2O         float64
# CFC-11      float64
# CFC-12      float64
# TSI         float64
# Aerosols    float64
# Temp        float64
# dtype: object
# ['Year', 'Month', 'MEI', 'CO2', 'CH4', 'N2O', 'CFC-11', 'CFC-12', 'TSI', 'Aerosols', 'Temp']
#    Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12        TSI  \
# 0  1983      5  2.556  345.96  1638.59  303.677  191.324  350.113  1366.1024
# 1  1983      6  2.167  345.52  1633.71  303.746  192.057  351.848  1366.1208
# 2  1983      7  1.741  344.15  1633.22  303.795  192.818  353.725  1366.2850
# 3  1983      8  1.130  342.25  1631.35  303.839  193.602  355.633  1366.4202
# 4  1983      9  0.428  340.17  1648.40  303.901  194.392  357.465  1366.2335
# 5  1983     10  0.002  340.30  1663.79  303.970  195.171  359.174  1366.0589
#
#    Aerosols   Temp
# 0    0.0863  0.109
# 1    0.0794  0.118
# ...

# %%
data_ori.drop('Year', axis=1, inplace=True)
data_ori.drop('Month', axis=1, inplace=True)

# %%
sns.pairplot(data_ori)

# %%
X_train = data_ori.drop('Temp', axis=1)[:284]
Y_train = data_ori['Temp'][:284]

# %%
from sklearn.linear_model import LinearRegression

lrmodel = LinearRegression()
lrmodel.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = lrmodel.predict(X_train)
lrmodel.score(X_train, Y_train)
# Out:
# 0.7508932770523443

# %%
X_test = data_ori.drop('Temp', axis=1)[284:]
Y_test_observed = data_ori['Temp'][284:]

# %%
y_test = lrmodel.predict(X_test)

# %%
plt.figure()
plt.plot(y_test)
plt.plot(Y_test_observed.)
plt.show()
